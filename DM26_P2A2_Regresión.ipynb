# %% [markdown]
# <a href="https://colab.research.google.com/github/ENRIKO-18/DataMining/blob/main/DM26_P2A2_Regresi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Regresión Lineal Simple y Múltiple
# **Objetivo:**
# Aplicar modelos de regresión lineal SIMPLEY MÚLTIPLE usando la librería Scikit-learn para:
#
# * Predecir una variable dependiente
# * Evaluar el modelo
# * Interpretar resultados

# %% [markdown]
# # Parte 1: Regresión Lineal Simple
# Utiliza el siguiente conjunto de datos:

# %%
import pandas as pd
import numpy as np
data = {"Horas_estudio": [1.5, 2.0, 3.0, 3.5, 4.0, 5.5, 6.0, 6.5, 7.0, 8.5,9.0, 10.5, 11.0, 12.5, 13.0, 14.5, 15.0, 16.5, 18.0, 19.5],
        "Calificacion": [45, 50, 48, 55, 60, 58, 65, 70, 68, 75,72, 80, 85, 82, 88, 90, 92, 95, 98, 100]}

df = pd.DataFrame(data)
df

# %% [markdown]
# **Actividades a realizar:**
# 1. Separa variables:
# * X = Horas_estudio
# * y = Calificacion
#
# 2. Divide los datos en entrenamiento y prueba (80/20)
# 3. Entrena un modelo de regresión lineal
# 4. Realiza predicciones
# 5. Evalúa el modelo con:
# * MAE
# * MSE
# * R²
# 6. Grafica:
# * Datos reales
# * Línea de regresión

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Separa variables:**
# * X = Horas_estudio
# * y = Calificacion

# %%
X =
y =

# %% [markdown]
# 2. Divide los datos en entrenamiento y prueba (80/20)

# %% [markdown]
# 3. Entrenamiento del modelo de regresión lineal

# %% [markdown]
# 4. Realiza predicciones

# %%
#Genera predicción de un VALOR de interés
import numpy as np
n_valor = np.array([[TU VALOR]])  # IMPORTANTE: formato 2D
prediccion = modelo.predict(n_valor)

print("Predicción:", prediccion)
# Out:
# Predicción: [54.19253623]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 5. Evalúa el modelo con:
# * MAE(*Mean absolute error*)
# * MSE(*Mean squared Error*)
# * R²

# %%
print("MAE:", )
print("MSE:", )
print("R2:",  )

# %% [markdown]
# **¿Qué intereptas de las métricas obtenidas? Desarrolla tu respuesta con base en los valores obtenidos.**
#
# * MAE- En promedio las predicciones fallaron por ≈ 4 puntos de calif. y aprox igul que MSE (raíz). Por lo que tenemos errores consistentes.
# * MSE >> MAE → hay outliers o errores grandes, que no es el Caso.
# * Dado que R² ≈ 0.94 → es un buen ajuste por lo que el modelo explica el 94%  de la variación.
#
# El dataset es pequeño (solo 8 datos). La relación parece casi perfectamente lineal.
#
# Entonces: El modelo puede estar sobreajustado al patrón simple del dataset y no necesariamente generalizar igual en datos reales.

# %% [markdown]
# 6. Grafica:
# * Datos reales
# * Línea de regresión

# %%
plt.scatter(X, y)
plt.plot(X, modelo.predict(X), linewidth=2)
plt.show()

# %% [markdown]
# ### La regresión lineal simple permite modelar y cuantificar la relación entre una variable independiente y una dependiente, proporcionando una ecuación que permite hacer predicciones. Sin embargo, su capacidad explicativa es limitada, ya que asume que una sola variable influye en el resultado.

# %% [markdown]
# #  Parte 2: Regresión Lineal Múltiple

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data2 = {
    "Horas_estudio": [1.5, 2.0, 3.0, 3.5, 4.0, 5.5, 6.0, 6.5, 7.0, 8.5,9.0, 10.5, 11.0, 12.5, 13.0, 14.5, 15.0, 16.5, 18.0, 19.5],
    "Horas_sueño": [5.0, 4.5, 6.0, 5.5, 7.0, 6.5, 5.0, 8.0, 7.5, 6.0,8.5, 7.0, 6.5, 8.0, 7.5, 8.5, 9.0, 8.0, 7.5, 8.0],
    "Ejercicio": [0.5, 0.0, 1.0, 0.5, 1.5, 1.0, 0.0, 2.0, 1.5, 1.0,2.5, 2.0, 1.5, 2.0, 1.0, 2.5, 2.0, 2.5, 3.0, 2.0],
    "Calificacion": [45, 50, 48, 55, 60, 58, 65, 70, 68, 75,72, 80, 85, 82, 88, 90, 92, 95, 98, 100]
}


df2 = pd.DataFrame(data2)
df2

# %% [markdown]
# Actividades
# 1. Define:
# * X = variables independientes (todas excepto Calificacion)
# * y = Calificacion
# 2. Divide en entrenamiento y prueba
# 3. Entrenamieto y predicción
# 4. Muestra:
# * Coeficientes del modelo
# * Intercepto
# * Escribe el modelo: La fórmula con base en los coeficientes y el valor del intercepto.
# 5. Evalúa con:
# * MAE
# * MSE
# * R²
# 6. Genera una predicción (y) proponiendo valores: Horas_estudio:x1 /Horas_sueño:x2/Ejercicio:x3
# 7. Interpretación general del modelo
# * a.  Intepreta los resutlados de la evaluación MSE y R2
# * b. ¿Qué variable influye más y cuál menos? (fíjate en los valores de los coeficientes obtenidos)
# * c. ¿Como es su desempeño con respecto al MODELO DE REGRESIÓN SIMPLE? ¿Qué modelo escogerías para este caso-simple o el múltiple? ¿Por Qué?

# %%
# 1 Separación en X, y

#2 División de los datos

#3 entrenamiento y predicción

#4 Coeficiente e intercepto


#5. Evalúación

# %% [markdown]
# 4. Escribe el modelo a partir de los coeficientes y el intercepto:
#
# $$y= $$

# %% [markdown]
# 6. Prediccción ejemplo:

# %%
#Predicción Propuesta (Horas_estudio,Horas_sueño, Ejercicio)

# %% [markdown]
# **7. Interpretación general del modelo**
# * a.
# * b.
# * c.
